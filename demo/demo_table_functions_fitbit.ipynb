# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip install datascience
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 725.0/725.0 kB 13.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 40.7 MB/s eta 0:00:00
# ...

# %%
from datascience import *

# %%
tbl=Table.read_table('/content/drive/MyDrive/IS296_Colab/demo/week5/fitbit-sleep.csv')
tbl
# Out:
# Start Time          | End Time           | Minutes Asleep | Minutes Awake | Number of Awakenings | Time in Bed | Minutes REM Sleep | Minutes Light Sleep | Minutes Deep Sleep
# 2022-09-25 12:21 AM | 2022-09-25 8:56 AM | 472            | 43            | 21                   | 515         | 128               | 257                 | 87
# 2022-09-23 10:00 PM | 2022-09-24 7:55 AM | 549            | 46            | 25                   | 595         | 165               | 303                 | 81
# 2022-09-22 11:53 PM | 2022-09-23 6:08 AM | 339            | 36            | 22                   | 375         | 96                | 212                 | 31
# 2022-09-21 10:57 PM | 2022-09-22 5:35 AM | 358            | 40            | 19                   | 398         | 94                | 199                 | 65
# 2022-09-20 11:52 PM | 2022-09-21 6:08 AM | 350            | 26            | 12                   | 376         | 103               | 187                 | 60
# ...

# %%
REM_sleep=tbl.column('Minutes REM Sleep')
deep_sleep=tbl.column('Minutes Deep Sleep')
awake = tbl.column('Minutes Awake')
total_sleep = tbl.column('Minutes Asleep')

# %%
REM_percentage = REM_sleep/total_sleep * 100
REM_percentage
# Out:
# array([ 27.11864407,  30.05464481,  28.31858407,  26.25698324,
#         29.42857143,  26.47058824,  26.07594937,  38.25      ,
#         24.05857741,  19.94818653,  -1.17647059,  12.03703704,
#         -1.36986301,  24.13793103,  -0.25445293,  25.51546392,
#         36.74540682,  -0.26455026,  25.51319648,  22.25913621])

# %%
SQI = (REM_sleep/total_sleep*100)*.4 + (deep_sleep/total_sleep*100)*.4 + (1-awake/total_sleep)*100*0.2

# %%
import numpy as np

# %%
np.mean(SQI)
# Out:
# 31.09941377810058

# %%
np.std(SQI)
# Out:
# 7.678951962819494

# %%
np.max(SQI)
# Out:
# 42.0

# %%
steps=Table.read_table('/content/drive/MyDrive/IS296_Colab/demo/week5/fitbit_excercise_2024.csv')
steps
# Out:
# Index | Date       | Day_of_Week | Calories Burned | Steps | Distance | Minutes Sedentary | Minutes Lightly Active | Minutes Fairly Active | Minutes Very Active | Activity Calories
# 1     | 2024-01-16 | Tue         | 1532            | 4604  | 1.92     | 774               | 215                    | 6                     | 1                   | 530
# 2     | 2024-01-17 | Wed         | 1476            | 4385  | 1.83     | 821               | 175                    | 6                     | 1                   | 452
# 3     | 2024-01-18 | Thur        | 1554            | 7766  | 3.24     | 833               | 136                    | 29                    | 18                  | 540
# 4     | 2024-01-19 | Fri         | 1515            | 5167  | 2.16     | 1,273             | 141                    | 7                     | 19                  | 471
# ...

# %% [markdown]
# What was the average calories burned on all Mondays
