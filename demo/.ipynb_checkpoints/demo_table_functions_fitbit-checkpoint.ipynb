# %%
from datascience import *

# %%
tbl=Table.read_table('https://raw.githubusercontent.com/lujiec2020/UMBC-IS296-Sp26/refs/heads/main/data/fitbit-sleep.csv')
tbl

# %%
#Q1: which night I slept the most, and how long did I sleep?

# %%
#Q2: During that sleep, what is the percentage are REM?

# %%
#Q3: How does it compare other days? you can use the average of other days’ REM as comparison.

# %%
# what are other curious quesetions you have about my sleep?
