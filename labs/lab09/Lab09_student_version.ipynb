# %%
# data science package
# !pip install datascience
from datascience import *
import numpy as np
#plotting functions
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
#Google text to speech package
# !pip install gTTS
from gtts import gTTS #Import Google Text to Speech
from IPython.display import Audio #Import Audio method from IPython's Display Class

# %%
#function to play the sound using Google text to speech
def play_sound(text):

  tts = gTTS(text)
  tts.save('1.wav')
  sound = '1.wav'
  return Audio(sound, autoplay=True)

play_sound('Hello World')

# %%
student_list=make_array('')

# %%
# Write code to randomly pick a classmate to play the game, and say it loud
# Create a function called choose_a_name, which take a input parameter of student name list
# use np.random.choice
# say it aloud using text-to-speech function (play_sound) provided

# %%
#Write code to randomly pick a cup
#Create a function called pick_a_cup, which takes no parameters
#Use no.random.choice to randomly select a number from 1, 2, and 3
#If #1 cup: print “data science questions”
#If #2 cup: print “funny questions”
#If #3 cup: print “candy”
#say it aloud using text-to-speech function (play_sound) provided

# %%
#Write a simulation function that can randomly pick a classmate for 1000 times, and return the number of the times that it choose a given name, test this function use your own name
#Your function should take two parameters: the list of classmate name and the name you are checking
#Your function should not have a for loop
